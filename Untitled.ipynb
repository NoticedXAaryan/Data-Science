# %%
print("test")
# Out:
# test

# %%
100+2357-3456789+4135
# Out:
# -3450197

# %%
a=int(input("enter = "))
if a<=99:
    print("HI!")
elif a>=100:
    print("HOLA")
# Out:
# enter = 100
# HOLA

# %%
a=int(input("enter = "))
b=int(input("enter = "))
print(a+b,"will be the sum of the no.")
# Out:
# enter = 156
# enter = 234
# 390 will be the sum of the no.
